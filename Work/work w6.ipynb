# %%
import pickle
from string import punctuation

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Load the data
import logging
logger = logging.getLogger("spacy")
logger.setLevel(logging.ERROR)

import dask.bag as db
import json

docs = db.read_text('../Data/arxiv-metadata-oai-snapshot.json').map(json.loads)

# %%
docs.take(1)
# Out:
# ({'id': '0704.0001',
#   'submitter': 'Pavel Nadolsky',
#   'authors': "C. Bal\\'azs, E. L. Berger, P. M. Nadolsky, C.-P. Yuan",
#   'title': 'Calculation of prompt diphoton production cross sections at Tevatron and\n  LHC energies',
#   'comments': '37 pages, 15 figures; published version',
#   'journal-ref': 'Phys.Rev.D76:013009,2007',
#   'doi': '10.1103/PhysRevD.76.013009',
#   'report-no': 'ANL-HEP-PR-07-12',
#   'categories': 'hep-ph',
#   'license': None,
#   'abstract': '  A fully differential calculation in perturbative quantum chromodynamics is\npresented for the production of massive photon pairs at hadron colliders. All\nnext-to-leading order perturbative contributions from quark-antiquark,\ngluon-(anti)quark, and gluon-gluon subprocesses are included, as well as\nall-orders resummation of initial-state gluon radiation valid at\nnext-to-next-to-leading logarithmic accuracy. The region of phase space is\nspecified in which the calculation is most reliable. Good agreement is\ndemonstrated with data from the Fermilab Tevatron, and predictions are made for\nmore detailed tests with CDF and DO data. Predictions are shown for\ndistributions of diphoton pairs produced at the energy of the Large Hadron\nCollider (LHC). Distributions of the diphoton pairs from the decay of a Higgs\nboson are contrasted with those produced from QCD processes at the LHC, showing\nthat enhanced sensitivity to the signal can be obtained with judicious\nselection of events.\n',
#   'versions': [{'version': 'v1', 'created': 'Mon, 2 Apr 2007 19:18:42 GMT'},
#    {'version': 'v2', 'created': 'Tue, 24 Jul 2007 20:10:27 GMT'}],
#   'update_date': '2008-11-26',
#   'authors_parsed': [['Balázs', 'C.', ''],
#    ['Berger', 'E. L.', ''],
#    ['Nadolsky', 'P. M.', ''],
#    ['Yuan', 'C. -P.', '']]},)

# %%
# Trimming the data
get_latest_version = lambda x: x['versions'][-1]['created']


# get only necessary fields of the metadata file
trim = lambda x: {'id': x['id'],
                  'authors': x['authors'],
                  'title': x['title'],
                  'doi': x['doi'],
                  'category':x['categories'].split(' '),
                  'abstract':x['abstract'],}

# filter for papers published on or after 2019-01-01
columns = ['id','category','abstract']
docs_df = (docs.filter(lambda x: int(get_latest_version(x).split(' ')[3]) > 2019)
           .map(trim).
           compute())

# convert to pandas
docs_df = pd.DataFrame(docs_df)

# %%
#save trimmed dataset for later use so we can skip the dataset trimming later:
docs_df.to_csv("../Data/trimmed_arxiv_docs.csv", index=False)

# %%
# Read docs from the file
docs_df = pd.read_csv('../Data/trimmed_arxiv_docs.csv')
# Out:
# /Users/miamijovic/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#The first 5 rows:
docs_df.head()
# Out:
#          id                                            authors  \
# 0  704.0479                                          T.Geisser
# 1  705.0825       Ram Gopal Vishwakarma (Zacatecas University)
# 2  705.4004                         Samy Skander Bahoura (IMJ)
# 3   705.406                        Ruy Exel and Artur O. Lopes
# 4  705.4151  Maria Deijfen, Henri van den Esker, Remco van ...
#
#                                                title  \
# 0               The affine part of the Picard scheme
# 1  Einstein's Theory of Gravity in the Presence o...
# 2  About Brezis-Merle Problem with Lipschitz cond...
# 3           C*- Algebras and Thermodynamic Formalism
# 4  A preferential attachment model with random in...
#
#                          doi                         category  \
# 0                        NaN           ['math.AG', 'math.KT']
# 1  10.1007/s10509-009-0016-8  ['gr-qc', 'astro-ph', 'hep-th']
# 2                        NaN                      ['math.AP']
# 3                        NaN           ['math.DS', 'math.OA']
# 4  10.1007/s11512-007-0067-4           ['math.PR', 'math.CO']
#
#                                             abstract
# 0    We describe the maximal torus and maximal un...
# 1    The mysterious `dark energy' needed to expla...
# 2    We give blow-up analysis for a Brezis-Merle'...
# 3    We present a detailed exposition (for a Dyna...
# 4    In this paper, a random graph process ${G(t)...

# %%
# Listing categories
categories = list(docs_df['category'].unique())
for i in categories:
    print(i)

# %%
# Split categories
def splitCategory(cat):
    tmp = cat.replace('[','').replace(']','')
    c = tmp.split(', ')
    c = [w.replace("'","") for w in c]
    return c

# %%
# Find main category
def findMainCat(categories):
    new_cat = list(dict.fromkeys([cat.split(".")[0] for cat in categories]))
    return new_cat

# %% [markdown]
# Cleaning the data

# %%
df = pd.read_csv("../Data/trimmed_arxiv_docs.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377629 entries, 0 to 377628
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        377629 non-null  object
#  1   authors   377629 non-null  object
#  2   title     377629 non-null  object
#  3   doi       117502 non-null  object
#  4   category  377629 non-null  object
#  5   abstract  377629 non-null  object
# dtypes: object(6)
# memory usage: 17.3+ MB

# %%
# Adding abstract word count
df['abstract_word_count'] = docs_df['abstract'].apply(lambda x: len(x.strip().split()))

# %%
df['abstract'].describe(include='all')
# Out:
# count                                                377629
# unique                                               377559
# top         This article focuses on the development of h...
# freq                                                      2
# Name: abstract, dtype: object

# %%
# Getting rid of duplicates
df.drop_duplicates(['abstract',], inplace=True)
df['abstract'].describe(include='all')
# Out:
# count                                                377559
# unique                                               377559
# top         The first report of phase separation in meta...
# freq                                                      1
# Name: abstract, dtype: object

# %% [markdown]
# NLP data processing

# %%
# Add the categories
df['list_categories'] = df.category.apply(splitCategory)
df['main_categories'] = df.list_categories.apply(findMainCat)

# %%
df
# Out:
#                       id                                            authors  \
# 0               704.0479                                          T.Geisser
# 1               705.0825       Ram Gopal Vishwakarma (Zacatecas University)
# 2               705.4004                         Samy Skander Bahoura (IMJ)
# 3                705.406                        Ruy Exel and Artur O. Lopes
# 4               705.4151  Maria Deijfen, Henri van den Esker, Remco van ...
# ...                  ...                                                ...
# 377624  quant-ph/0507088                                         Rahul Jain
# 377625  quant-ph/0604056                  Scott Aaronson and Greg Kuperberg
# 377626  quant-ph/0612050                             Igor Devetak, Jon Yard
# 377627  quant-ph/0701163                                       Daegene Song
# 377628  quant-ph/9806088           J. Eisert, M. Wilkens, and M. Lewenstein
#
#                                                     title  \
# 0                    The affine part of the Picard scheme
# 1       Einstein's Theory of Gravity in the Presence o...
# 2       About Brezis-Merle Problem with Lipschitz cond...
# 3                C*- Algebras and Thermodynamic Formalism
# 4       A preferential attachment model with random in...
# ...                                                   ...
# 377624                   Chain-rules for channel capacity
# 377625         Quantum Versus Classical Proofs and Advice
# 377626  The exact cost of redistributing multipartite ...
# 377627                   Does Observation Create Reality?
# 377628               Quantum Games and Quantum Strategies
#
#                                    doi                         category  \
# 0                                  NaN           ['math.AG', 'math.KT']
# 1            10.1007/s10509-009-0016-8  ['gr-qc', 'astro-ph', 'hep-th']
# 2                                  NaN                      ['math.AP']
# 3                                  NaN           ['math.DS', 'math.OA']
# 4            10.1007/s11512-007-0067-4           ['math.PR', 'math.CO']
# ...                                ...                              ...
# 377624                             NaN                     ['quant-ph']
# 377625                             NaN            ['quant-ph', 'cs.CC']
# 377626  10.1103/PhysRevLett.100.230501                     ['quant-ph']
# 377627                             NaN                     ['quant-ph']
# 377628     10.1103/PhysRevLett.83.3077                     ['quant-ph']
#
#                                                  abstract  \
# 0         We describe the maximal torus and maximal un...
# 1         The mysterious `dark energy' needed to expla...
# 2         We give blow-up analysis for a Brezis-Merle'...
# 3         We present a detailed exposition (for a Dyna...
# 4         In this paper, a random graph process ${G(t)...
# ...                                                   ...
# 377624    We show some chain-rules for the capacity of...
# 377625    This paper studies whether quantum proofs ar...
# 377626    How correlated are two quantum systems from ...
# 377627    It has been suggested that the locality of i...
# 377628    We investigate the quantization of non-zero ...
#
#         abstract_word_count            list_categories  \
# 0                        21         [math.AG, math.KT]
# 1                        83  [gr-qc, astro-ph, hep-th]
# 2                        39                  [math.AP]
# 3                       110         [math.DS, math.OA]
# 4                       152         [math.PR, math.CO]
# ...                     ...                        ...
# 377624                   32                 [quant-ph]
# 377625                  174          [quant-ph, cs.CC]
# 377626                  118                 [quant-ph]
# 377627                  112                 [quant-ph]
# 377628                   49                 [quant-ph]
#
#                   main_categories
# 0                          [math]
# 1       [gr-qc, astro-ph, hep-th]
# 2                          [math]
# 3                          [math]
# 4                          [math]
# ...                           ...
# 377624                 [quant-ph]
# 377625             [quant-ph, cs]
# 377626                 [quant-ph]
# 377627                 [quant-ph]
# 377628                 [quant-ph]
#
# [377559 rows x 9 columns]

# %%
# Create CS and Random dataframes
bool_series = ["cs" in cat for cat in df.main_categories]
df_cs = df[bool_series]

# %%
df_cs
# Out:
#                       id                                            authors  \
# 30              801.3697                                     George I. Bell
# 39              805.1293                                   Avik Chakraborty
# 43              806.0557  Qin Li, Chengqing Li, Chunhui Wu, Dongyang Lon...
# 57              809.2093                            Troy Lee, Adi Shraibman
# 65               810.484  Dorit Aharonov, Michael Ben-Or, Fernando G.S.L...
# ...                  ...                                                ...
# 377513        cs/0606037                  Andrej Bogdanov and Luca Trevisan
# 377514        cs/0608050                    Pascal Pons and Matthieu Latapy
# 377515        cs/0610128                       Daniel Lemire and Owen Kaser
# 377547      math/0008020              Matthieu Latapy and Thi Ha Duong Phan
# 377625  quant-ph/0604056                  Scott Aaronson and Greg Kuperberg
#
#                                                     title  \
# 30                             The mathematics of Septoku
# 39       Testability of Reversible Iterative Logic Arrays
# 43      An efficient and provably secure arbitrated qu...
# 57      An approximation algorithm for approximation rank
# 65      The Pursuit of Uniqueness: Extending Valiant-V...
# ...                                                   ...
# 377513                            Average-Case Complexity
# 377514  Post-Processing Hierarchical Community Structu...
# 377515  Hierarchical Bin Buffering: Online Local Momen...
# 377547  The Lattice of integer partitions and its infi...
# 377625         Quantum Versus Classical Proofs and Advice
#
#                                doi  \
# 30                             NaN
# 39                             NaN
# 43                             NaN
# 57                             NaN
# 65                             NaN
# ...                            ...
# 377513                         NaN
# 377514   10.1016/j.tcs.2010.11.041
# 377515     10.1145/1328911.1328925
# 377547  10.1016/j.disc.2008.02.002
# 377625                         NaN
#
#                                                  category  \
# 30                        ['math.CO', 'cs.DM', 'math.GM']
# 39                                              ['cs.OH']
# 43                                  ['quant-ph', 'cs.CR']
# 57                                              ['cs.CC']
# 65                                  ['quant-ph', 'cs.CC']
# ...                                                   ...
# 377513                                          ['cs.CC']
# 377514     ['cs.DS', 'cond-mat.dis-nn', 'physics.soc-ph']
# 377515                                 ['cs.DS', 'cs.DB']
# 377547  ['math.CO', 'cs.NA', 'math.DS', 'math.NA', 'ma...
# 377625                              ['quant-ph', 'cs.CC']
#
#                                                  abstract  \
# 30        Septoku is a Sudoku variant invented by Bruc...
# 39        Iterative Logic Arrays (ILAs) are ideal as V...
# 43        In this paper, an efficient arbitrated quant...
# 57        One of the strongest techniques available fo...
# 65        Valiant-Vazirani showed in 1985 [VV85] that ...
# ...                                                   ...
# 377513    We survey the average-case complexity of pro...
# 377514    Dense sub-graphs of sparse graphs (communiti...
# 377515    Local moments are used for local regression,...
# 377547    In this paper, we use a simple discrete dyna...
# 377625    This paper studies whether quantum proofs ar...
#
#         abstract_word_count                              list_categories  \
# 30                       93                    [math.CO, cs.DM, math.GM]
# 39                      227                                      [cs.OH]
# 43                      120                            [quant-ph, cs.CR]
# 57                      188                                      [cs.CC]
# 65                      195                            [quant-ph, cs.CC]
# ...                     ...                                          ...
# 377513                  170                                      [cs.CC]
# 377514                  122     [cs.DS, cond-mat.dis-nn, physics.soc-ph]
# 377515                  184                               [cs.DS, cs.DB]
# 377547                  152  [math.CO, cs.NA, math.DS, math.NA, math.NT]
# 377625                  174                            [quant-ph, cs.CC]
#
#                 main_categories
# 30                   [math, cs]
# 39                         [cs]
# 43               [quant-ph, cs]
# 57                         [cs]
# 65               [quant-ph, cs]
# ...                         ...
# 377513                     [cs]
# 377514  [cs, cond-mat, physics]
# 377515                     [cs]
# 377547               [math, cs]
# 377625           [quant-ph, cs]
#
# [151713 rows x 9 columns]

# %%
# Non-CS df
bool_series = ["cs" not in cat for cat in df.main_categories]
df_random = df[bool_series]

# %%
df_random
# Out:
#                       id                                            authors  \
# 0               704.0479                                          T.Geisser
# 1               705.0825       Ram Gopal Vishwakarma (Zacatecas University)
# 2               705.4004                         Samy Skander Bahoura (IMJ)
# 3                705.406                        Ruy Exel and Artur O. Lopes
# 4               705.4151  Maria Deijfen, Henri van den Esker, Remco van ...
# ...                  ...                                                ...
# 377623  quant-ph/0411039                                     Sofia Wechsler
# 377624  quant-ph/0507088                                         Rahul Jain
# 377626  quant-ph/0612050                             Igor Devetak, Jon Yard
# 377627  quant-ph/0701163                                       Daegene Song
# 377628  quant-ph/9806088           J. Eisert, M. Wilkens, and M. Lewenstein
#
#                                                     title  \
# 0                    The affine part of the Picard scheme
# 1       Einstein's Theory of Gravity in the Presence o...
# 2       About Brezis-Merle Problem with Lipschitz cond...
# 3                C*- Algebras and Thermodynamic Formalism
# 4       A preferential attachment model with random in...
# ...                                                   ...
# 377623         What was in the apparatus before the click
# 377624                   Chain-rules for channel capacity
# 377626  The exact cost of redistributing multipartite ...
# 377627                   Does Observation Create Reality?
# 377628               Quantum Games and Quantum Strategies
#
#                                    doi                         category  \
# 0                                  NaN           ['math.AG', 'math.KT']
# 1            10.1007/s10509-009-0016-8  ['gr-qc', 'astro-ph', 'hep-th']
# 2                                  NaN                      ['math.AP']
# 3                                  NaN           ['math.DS', 'math.OA']
# 4            10.1007/s11512-007-0067-4           ['math.PR', 'math.CO']
# ...                                ...                              ...
# 377623                             NaN                     ['quant-ph']
# 377624                             NaN                     ['quant-ph']
# 377626  10.1103/PhysRevLett.100.230501                     ['quant-ph']
# 377627                             NaN                     ['quant-ph']
# 377628     10.1103/PhysRevLett.83.3077                     ['quant-ph']
#
#                                                  abstract  \
# 0         We describe the maximal torus and maximal un...
# 1         The mysterious `dark energy' needed to expla...
# 2         We give blow-up analysis for a Brezis-Merle'...
# 3         We present a detailed exposition (for a Dyna...
# 4         In this paper, a random graph process ${G(t)...
# ...                                                   ...
# 377623    When a quantum system is described by a wave...
# 377624    We show some chain-rules for the capacity of...
# 377626    How correlated are two quantum systems from ...
# 377627    It has been suggested that the locality of i...
# 377628    We investigate the quantization of non-zero ...
#
#         abstract_word_count            list_categories  \
# 0                        21         [math.AG, math.KT]
# 1                        83  [gr-qc, astro-ph, hep-th]
# 2                        39                  [math.AP]
# 3                       110         [math.DS, math.OA]
# 4                       152         [math.PR, math.CO]
# ...                     ...                        ...
# 377623                  144                 [quant-ph]
# 377624                   32                 [quant-ph]
# 377626                  118                 [quant-ph]
# 377627                  112                 [quant-ph]
# 377628                   49                 [quant-ph]
#
#                   main_categories
# 0                          [math]
# 1       [gr-qc, astro-ph, hep-th]
# 2                          [math]
# 3                          [math]
# 4                          [math]
# ...                           ...
# 377623                 [quant-ph]
# 377624                 [quant-ph]
# 377626                 [quant-ph]
# 377627                 [quant-ph]
# 377628                 [quant-ph]
#
# [225846 rows x 9 columns]

# %%
# Reduce the size of the data
df_cs = df_cs.sample(10000, random_state=42)
df_random = df_random.sample(10000, random_state=42)

# %%
#Define stopwords (scientific stopwords)
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
stopwords = STOP_WORDS

# %%
#Define the cleaner - remove punctuation and stopwords
def cleanPunct(text):
    return [w for w in text if w not in punctuation]

# %%
# make everything lowercase
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
def low(instance):
    tokens = word_tokenize(instance)
    return [w.lower() for w in tokens if w not in ["(", ")"]]
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/miamijovic/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Create column with lowercase text
df_cs['cleaned'] = df_cs.abstract.apply(low)
df_random['cleaned'] = df_random.abstract.apply(low)

# %%
# Make ngrams
from nltk.util import ngrams

def bigrams(arr):
    return list(ngrams(arr, 2))

def trigrams(arr):
    return list(ngrams(arr,3))

# %%
#apply cleaning punctiation on unigrams
df_cs['cleaned'] = df_cs.cleaned.apply(cleanPunct)
df_random['cleaned'] = df_random.cleaned.apply(cleanPunct)
# Creating ngrams
df_cs['bigrams'] = df_cs.cleaned.apply(bigrams)
df_random['bigrams'] = df_random.cleaned.apply(bigrams)
df_cs['trigrams'] = df_cs.cleaned.apply(trigrams)
df_random['trigrams'] = df_random.cleaned.apply(trigrams)

# %%
# View dataframe
df_cs
# Out:
#                 id                                            authors  \
# 92635   2004.03874                        Italo Atzeni and Marco Maso
# 160796  2008.09084  Devendra Singh Sachan and Yuhao Zhang and Peng...
# 304315  2106.02562                        Zhaoxin Luo and Michael Zhu
# 21770   1905.04523  Supritam Bhattacharjee, Devraj Mandal, Soma Bi...
# 122056  2006.03552  Ian Abraham, Ahalya Prabhakar and Todd D. Murphey
# ...            ...                                                ...
# 244932  2102.04454  Mohammadreza Zandehshahvar, Yashar Kiarashi, M...
# 358175  2109.11365                                Xiaoran Wu, Jia Jia
# 201886  2011.05149              Eva van Weenen and Stefan Feuerriegel
# 82646     2003.083  Ali Baheri, Ilya Kolmanovsky, Anouck Girard, H...
# 59431   2001.09978  Luyao Niu, Bhaskar Ramasubramanian, Andrew Cla...
#
#                                                     title  \
# 92635                 Full-Duplex Radios for Edge Caching
# 160796  Do Syntax Trees Help Pre-trained Transformers ...
# 304315  Recurrent Neural Networks with Mixed Hierarchi...
# 21770   Multi-class Novelty Detection Using Mix-up Tec...
# 122056  An Ergodic Measure for Active Learning From Eq...
# ...                                                   ...
# 244932  Manifold Learning for Knowledge Discovery and ...
# 358175             Tumera: Tutor of Photography Beginners
# 201886      Estimating Risk-Adjusted Hospital Performance
# 82646   Vision-Based Autonomous Driving: A Model Learn...
# 59431   Control Synthesis for Cyber-Physical Systems t...
#
#                                   doi                         category  \
# 92635                             NaN             ['cs.IT', 'math.IT']
# 160796                            NaN                        ['cs.CL']
# 304315                            NaN                        ['cs.CL']
# 21770                             NaN                        ['cs.CV']
# 122056                            NaN                        ['cs.RO']
# ...                               ...                              ...
# 244932                            NaN      ['physics.optics', 'cs.LG']
# 358175                            NaN                        ['cs.HC']
# 201886                            NaN    ['stat.AP', 'cs.AI', 'cs.LG']
# 82646                             NaN  ['eess.SY', 'cs.SY', 'eess.SP']
# 59431   10.1109/ICCPS48487.2020.00023             ['eess.SY', 'cs.SY']
#
#                                                  abstract  \
# 92635     This chapter focuses on the performance enha...
# 160796    Much recent work suggests that incorporating...
# 304315    Hierarchical structures exist in both lingui...
# 21770     Multi-class novelty detection is increasingl...
# 122056    This paper develops KL-Ergodic Exploration f...
# ...                                                   ...
# 244932    Here, we present a new approach based on man...
# 358175    With the popularity of photographic equipmen...
# 201886    The quality of healthcare provided by hospit...
# 82646     We present an integrated approach for percep...
# 59431     This paper studies the synthesis of controll...
#
#         abstract_word_count            list_categories main_categories  \
# 92635                   271           [cs.IT, math.IT]      [cs, math]
# 160796                  193                    [cs.CL]            [cs]
# 304315                  160                    [cs.CL]            [cs]
# 21770                   245                    [cs.CV]            [cs]
# 122056                  174                    [cs.RO]            [cs]
# ...                     ...                        ...             ...
# 244932                  100    [physics.optics, cs.LG]   [physics, cs]
# 358175                  126                    [cs.HC]            [cs]
# 201886                  253    [stat.AP, cs.AI, cs.LG]      [stat, cs]
# 82646                   166  [eess.SY, cs.SY, eess.SP]      [eess, cs]
# 59431                   168           [eess.SY, cs.SY]      [eess, cs]
#
#                                                   cleaned  \
# 92635   [this, chapter, focuses, on, the, performance,...
# 160796  [much, recent, work, suggests, that, incorpora...
# 304315  [hierarchical, structures, exist, in, both, li...
# 21770   [multi-class, novelty, detection, is, increasi...
# 122056  [this, paper, develops, kl-ergodic, exploratio...
# ...                                                   ...
# 244932  [here, we, present, a, new, approach, based, o...
# 358175  [with, the, popularity, of, photographic, equi...
# 201886  [the, quality, of, healthcare, provided, by, h...
# 82646   [we, present, an, integrated, approach, for, p...
# 59431   [this, paper, studies, the, synthesis, of, con...
#
#                                                   bigrams  \
# 92635   [(this, chapter), (chapter, focuses), (focuses...
# 160796  [(much, recent), (recent, work), (work, sugges...
# 304315  [(hierarchical, structures), (structures, exis...
# 21770   [(multi-class, novelty), (novelty, detection),...
# 122056  [(this, paper), (paper, develops), (develops, ...
# ...                                                   ...
# 244932  [(here, we), (we, present), (present, a), (a, ...
# 358175  [(with, the), (the, popularity), (popularity, ...
# 201886  [(the, quality), (quality, of), (of, healthcar...
# 82646   [(we, present), (present, an), (an, integrated...
# 59431   [(this, paper), (paper, studies), (studies, th...
#
#                                                  trigrams
# 92635   [(this, chapter, focuses), (chapter, focuses, ...
# 160796  [(much, recent, work), (recent, work, suggests...
# 304315  [(hierarchical, structures, exist), (structure...
# 21770   [(multi-class, novelty, detection), (novelty, ...
# 122056  [(this, paper, develops), (paper, develops, kl...
# ...                                                   ...
# 244932  [(here, we, present), (we, present, a), (prese...
# 358175  [(with, the, popularity), (the, popularity, of...
# 201886  [(the, quality, of), (quality, of, healthcare)...
# 82646   [(we, present, an), (present, an, integrated),...
# 59431   [(this, paper, studies), (paper, studies, the)...
#
# [10000 rows x 12 columns]

# %%
def hyphenate(words, n):
    if(n==2):
        return [w[0]+'-'+w[1] for w in words]
    if(n==3):
        return [w[0]+'-'+w[1]+'-'+w[2] for w in words]

# %% [markdown]
# Dictionaties and most frequent term analysis

# %%
# Create dict func
def createDict(data):
    vocab = {}
    for instance in data:
        d = Counter(instance)
        for w in d.keys():
            if w in vocab:
                vocab[w] += d[w]
            else:
                vocab[w] = d[w]
    return dict(sorted(vocab.items(), key=lambda item: item[1], reverse=True))

# %%
from collections import Counter
unigram_cs = createDict(df_cs['cleaned'])
bigram_cs = createDict(df_cs['bigrams'])
trigram_cs = createDict(df_cs['trigrams'])

unigram_rand = createDict(df_random['cleaned'])
bigram_rand = createDict(df_random['bigrams'])
trigram_rand = createDict(df_random['trigrams'])

# %%
print(len(trigram_cs))
# Out:
# 1235555

# %%
# Removing stopwords and punctuation
def clean(text):
    return [w for w in text if w not in punctuation and w not in stopwords]

# %%
df_cs['cleaned'] = df_cs.cleaned.apply(clean)
df_random['cleaned'] = df_random.cleaned.apply(clean)
df_cs['bigrams'] = df_cs.cleaned.apply(bigrams)
df_random['bigrams'] = df_random.cleaned.apply(bigrams)
df_cs['trigrams'] = df_cs.cleaned.apply(trigrams)
df_random['trigrams'] = df_random.cleaned.apply(trigrams)

# %%
df_cs
# Out:
#                 id                                            authors  \
# 92635   2004.03874                        Italo Atzeni and Marco Maso
# 160796  2008.09084  Devendra Singh Sachan and Yuhao Zhang and Peng...
# 304315  2106.02562                        Zhaoxin Luo and Michael Zhu
# 21770   1905.04523  Supritam Bhattacharjee, Devraj Mandal, Soma Bi...
# 122056  2006.03552  Ian Abraham, Ahalya Prabhakar and Todd D. Murphey
# ...            ...                                                ...
# 244932  2102.04454  Mohammadreza Zandehshahvar, Yashar Kiarashi, M...
# 358175  2109.11365                                Xiaoran Wu, Jia Jia
# 201886  2011.05149              Eva van Weenen and Stefan Feuerriegel
# 82646     2003.083  Ali Baheri, Ilya Kolmanovsky, Anouck Girard, H...
# 59431   2001.09978  Luyao Niu, Bhaskar Ramasubramanian, Andrew Cla...
#
#                                                     title  \
# 92635                 Full-Duplex Radios for Edge Caching
# 160796  Do Syntax Trees Help Pre-trained Transformers ...
# 304315  Recurrent Neural Networks with Mixed Hierarchi...
# 21770   Multi-class Novelty Detection Using Mix-up Tec...
# 122056  An Ergodic Measure for Active Learning From Eq...
# ...                                                   ...
# 244932  Manifold Learning for Knowledge Discovery and ...
# 358175             Tumera: Tutor of Photography Beginners
# 201886      Estimating Risk-Adjusted Hospital Performance
# 82646   Vision-Based Autonomous Driving: A Model Learn...
# 59431   Control Synthesis for Cyber-Physical Systems t...
#
#                                   doi                         category  \
# 92635                             NaN             ['cs.IT', 'math.IT']
# 160796                            NaN                        ['cs.CL']
# 304315                            NaN                        ['cs.CL']
# 21770                             NaN                        ['cs.CV']
# 122056                            NaN                        ['cs.RO']
# ...                               ...                              ...
# 244932                            NaN      ['physics.optics', 'cs.LG']
# 358175                            NaN                        ['cs.HC']
# 201886                            NaN    ['stat.AP', 'cs.AI', 'cs.LG']
# 82646                             NaN  ['eess.SY', 'cs.SY', 'eess.SP']
# 59431   10.1109/ICCPS48487.2020.00023             ['eess.SY', 'cs.SY']
#
#                                                  abstract  \
# 92635     This chapter focuses on the performance enha...
# 160796    Much recent work suggests that incorporating...
# 304315    Hierarchical structures exist in both lingui...
# 21770     Multi-class novelty detection is increasingl...
# 122056    This paper develops KL-Ergodic Exploration f...
# ...                                                   ...
# 244932    Here, we present a new approach based on man...
# 358175    With the popularity of photographic equipmen...
# 201886    The quality of healthcare provided by hospit...
# 82646     We present an integrated approach for percep...
# 59431     This paper studies the synthesis of controll...
#
#         abstract_word_count            list_categories main_categories  \
# 92635                   271           [cs.IT, math.IT]      [cs, math]
# 160796                  193                    [cs.CL]            [cs]
# 304315                  160                    [cs.CL]            [cs]
# 21770                   245                    [cs.CV]            [cs]
# 122056                  174                    [cs.RO]            [cs]
# ...                     ...                        ...             ...
# 244932                  100    [physics.optics, cs.LG]   [physics, cs]
# 358175                  126                    [cs.HC]            [cs]
# 201886                  253    [stat.AP, cs.AI, cs.LG]      [stat, cs]
# 82646                   166  [eess.SY, cs.SY, eess.SP]      [eess, cs]
# 59431                   168           [eess.SY, cs.SY]      [eess, cs]
#
#                                                   cleaned  \
# 92635   [chapter, focuses, performance, enhancement, b...
# 160796  [recent, work, suggests, incorporating, syntax...
# 304315  [hierarchical, structures, exist, linguistics,...
# 21770   [multi-class, novelty, detection, increasingly...
# 122056  [paper, develops, kl-ergodic, exploration, equ...
# ...                                                   ...
# 244932  [present, new, approach, based, manifold, lear...
# 358175  [popularity, photographic, equipment, people, ...
# 201886  [quality, healthcare, provided, hospitals, sub...
# 82646   [present, integrated, approach, perception, co...
# 59431   [paper, studies, synthesis, controllers, cyber...
#
#                                                   bigrams  \
# 92635   [(chapter, focuses), (focuses, performance), (...
# 160796  [(recent, work), (work, suggests), (suggests, ...
# 304315  [(hierarchical, structures), (structures, exis...
# 21770   [(multi-class, novelty), (novelty, detection),...
# 122056  [(paper, develops), (develops, kl-ergodic), (k...
# ...                                                   ...
# 244932  [(present, new), (new, approach), (approach, b...
# 358175  [(popularity, photographic), (photographic, eq...
# 201886  [(quality, healthcare), (healthcare, provided)...
# 82646   [(present, integrated), (integrated, approach)...
# 59431   [(paper, studies), (studies, synthesis), (synt...
#
#                                                  trigrams
# 92635   [(chapter, focuses, performance), (focuses, pe...
# 160796  [(recent, work, suggests), (work, suggests, in...
# 304315  [(hierarchical, structures, exist), (structure...
# 21770   [(multi-class, novelty, detection), (novelty, ...
# 122056  [(paper, develops, kl-ergodic), (develops, kl-...
# ...                                                   ...
# 244932  [(present, new, approach), (new, approach, bas...
# 358175  [(popularity, photographic, equipment), (photo...
# 201886  [(quality, healthcare, provided), (healthcare,...
# 82646   [(present, integrated, approach), (integrated,...
# 59431   [(paper, studies, synthesis), (studies, synthe...
#
# [10000 rows x 12 columns]

# %%
unigram_cs = createDict(df_cs['cleaned'])
bigram_cs = createDict(df_cs['bigrams'])
trigram_cs = createDict(df_cs['trigrams'])

unigram_rand = createDict(df_random['cleaned'])
bigram_rand = createDict(df_random['bigrams'])
trigram_rand = createDict(df_random['trigrams'])

# %%
print(trigram_cs)

#trigrams - 20+
#bigrams - 40+
#unigrams - quite irrelevant, but maybe 100+

# %%
# Trim ngrams 
def trim(d, num):
    return dict((k, v) for k, v in d.items() if v>=num)

# %%
trim_value = 7
unigram_cs = trim(unigram_cs, trim_value)
unigram_rand = trim(unigram_rand, trim_value)
bigram_cs = trim(bigram_cs, trim_value)
bigram_rand = trim(bigram_rand, trim_value)
trigram_cs = trim(trigram_cs, trim_value)
trigram_rand = trim(trigram_rand, trim_value)

# %%
print(len(trigram_rand))
# Out:
# 610

# %%
df_cs
# Out:
#                 id                                            authors  \
# 92635   2004.03874                        Italo Atzeni and Marco Maso
# 160796  2008.09084  Devendra Singh Sachan and Yuhao Zhang and Peng...
# 304315  2106.02562                        Zhaoxin Luo and Michael Zhu
# 21770   1905.04523  Supritam Bhattacharjee, Devraj Mandal, Soma Bi...
# 122056  2006.03552  Ian Abraham, Ahalya Prabhakar and Todd D. Murphey
# ...            ...                                                ...
# 244932  2102.04454  Mohammadreza Zandehshahvar, Yashar Kiarashi, M...
# 358175  2109.11365                                Xiaoran Wu, Jia Jia
# 201886  2011.05149              Eva van Weenen and Stefan Feuerriegel
# 82646     2003.083  Ali Baheri, Ilya Kolmanovsky, Anouck Girard, H...
# 59431   2001.09978  Luyao Niu, Bhaskar Ramasubramanian, Andrew Cla...
#
#                                                     title  \
# 92635                 Full-Duplex Radios for Edge Caching
# 160796  Do Syntax Trees Help Pre-trained Transformers ...
# 304315  Recurrent Neural Networks with Mixed Hierarchi...
# 21770   Multi-class Novelty Detection Using Mix-up Tec...
# 122056  An Ergodic Measure for Active Learning From Eq...
# ...                                                   ...
# 244932  Manifold Learning for Knowledge Discovery and ...
# 358175             Tumera: Tutor of Photography Beginners
# 201886      Estimating Risk-Adjusted Hospital Performance
# 82646   Vision-Based Autonomous Driving: A Model Learn...
# 59431   Control Synthesis for Cyber-Physical Systems t...
#
#                                   doi                         category  \
# 92635                             NaN             ['cs.IT', 'math.IT']
# 160796                            NaN                        ['cs.CL']
# 304315                            NaN                        ['cs.CL']
# 21770                             NaN                        ['cs.CV']
# 122056                            NaN                        ['cs.RO']
# ...                               ...                              ...
# 244932                            NaN      ['physics.optics', 'cs.LG']
# 358175                            NaN                        ['cs.HC']
# 201886                            NaN    ['stat.AP', 'cs.AI', 'cs.LG']
# 82646                             NaN  ['eess.SY', 'cs.SY', 'eess.SP']
# 59431   10.1109/ICCPS48487.2020.00023             ['eess.SY', 'cs.SY']
#
#                                                  abstract  \
# 92635     This chapter focuses on the performance enha...
# 160796    Much recent work suggests that incorporating...
# 304315    Hierarchical structures exist in both lingui...
# 21770     Multi-class novelty detection is increasingl...
# 122056    This paper develops KL-Ergodic Exploration f...
# ...                                                   ...
# 244932    Here, we present a new approach based on man...
# 358175    With the popularity of photographic equipmen...
# 201886    The quality of healthcare provided by hospit...
# 82646     We present an integrated approach for percep...
# 59431     This paper studies the synthesis of controll...
#
#         abstract_word_count            list_categories main_categories  \
# 92635                   271           [cs.IT, math.IT]      [cs, math]
# 160796                  193                    [cs.CL]            [cs]
# 304315                  160                    [cs.CL]            [cs]
# 21770                   245                    [cs.CV]            [cs]
# 122056                  174                    [cs.RO]            [cs]
# ...                     ...                        ...             ...
# 244932                  100    [physics.optics, cs.LG]   [physics, cs]
# 358175                  126                    [cs.HC]            [cs]
# 201886                  253    [stat.AP, cs.AI, cs.LG]      [stat, cs]
# 82646                   166  [eess.SY, cs.SY, eess.SP]      [eess, cs]
# 59431                   168           [eess.SY, cs.SY]      [eess, cs]
#
#                                                   cleaned  \
# 92635   [chapter, focuses, performance, enhancement, b...
# 160796  [recent, work, suggests, incorporating, syntax...
# 304315  [hierarchical, structures, exist, linguistics,...
# 21770   [multi-class, novelty, detection, increasingly...
# 122056  [paper, develops, kl-ergodic, exploration, equ...
# ...                                                   ...
# 244932  [present, new, approach, based, manifold, lear...
# 358175  [popularity, photographic, equipment, people, ...
# 201886  [quality, healthcare, provided, hospitals, sub...
# 82646   [present, integrated, approach, perception, co...
# 59431   [paper, studies, synthesis, controllers, cyber...
#
#                                                   bigrams  \
# 92635   [(chapter, focuses), (focuses, performance), (...
# 160796  [(recent, work), (work, suggests), (suggests, ...
# 304315  [(hierarchical, structures), (structures, exis...
# 21770   [(multi-class, novelty), (novelty, detection),...
# 122056  [(paper, develops), (develops, kl-ergodic), (k...
# ...                                                   ...
# 244932  [(present, new), (new, approach), (approach, b...
# 358175  [(popularity, photographic), (photographic, eq...
# 201886  [(quality, healthcare), (healthcare, provided)...
# 82646   [(present, integrated), (integrated, approach)...
# 59431   [(paper, studies), (studies, synthesis), (synt...
#
#                                                  trigrams
# 92635   [(chapter, focuses, performance), (focuses, pe...
# 160796  [(recent, work, suggests), (work, suggests, in...
# 304315  [(hierarchical, structures, exist), (structure...
# 21770   [(multi-class, novelty, detection), (novelty, ...
# 122056  [(paper, develops, kl-ergodic), (develops, kl-...
# ...                                                   ...
# 244932  [(present, new, approach), (new, approach, bas...
# 358175  [(popularity, photographic, equipment), (photo...
# 201886  [(quality, healthcare, provided), (healthcare,...
# 82646   [(present, integrated, approach), (integrated,...
# 59431   [(paper, studies, synthesis), (studies, synthe...
#
# [10000 rows x 12 columns]

# %% [markdown]
# Feature Selection on CS vs Random

# %%
#CHI-Square stastic where:
# a - number of times t and c co-occur 11
# b - number of times t occurs w/o c 10
# c - number of times c occurs w/o t 01
# d - number of times neither c nor t occur 00
def chi_square(n,a,b,c,d):
    return n*((a*d-c*b)**2)/((a+c)*(b+d)*(a+b)*(c+d))

# %%
def selectKbest(features, k):
    features = {a: v for a, v in sorted(features.items(), key=lambda item: item[1], reverse=True)}
    features = {a: features[a] for a in list(features)[:k]}
    return features

# %%
def findOccurrences(term, C, notC):
    a = 0
    b = 0
    c = 0
    d = 0
    for item in C:
        if term in item:
            a += 1
        else:
            c += 1
    for item in notC:
        if term in item:
            b += 1
        else:
            d += 1
    return a,b,c,d

# %%
# Calculate chi2 values for each word
from collections import Counter

def createTermLists(cat, nonCat):
    # Find number of times term and class co-occur
    wordsC = Counter()
    for items in cat:
        wordsC = wordsC + Counter(items)
    return wordsC

# %%
def findChiValues(cat, nonCat):
    wordsC = createTermLists(cat, nonCat)
    chi_values = {}
    for term in wordsC:
        a,b,c,d = findOccurrences(term, cat, nonCat)
        n = len(cat) + len(nonCat)
        chi_values[term] = chi_square(n, a, b, c, d)
    return chi_values

# %%
chi_values_uni = findChiValues(df_cs.cleaned, df_random.cleaned)

# %%
print(len(chi_values_uni))
# Out:
# 53105

# %%
chi_values_bi = findChiValues(df_cs.bigrams, df_random.bigrams)
chi_values_tri = findChiValues(df_cs.trigrams, df_random.trigrams)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-144-680290e2886b> in <module>
# ----> 1 chi_values_bi = findChiValues(df_cs.bigrams, df_random.bigrams)
#       2 chi_values_tri = findChiValues(df_cs.trigrams, df_random.trigrams)
#
# <ipython-input-62-d023c8b83d0a> in findChiValues(cat, nonCat)
#       3     chi_values = {}
#       4     for term in wordsC:
# ----> 5         a,b,c,d = findOccurrences(term, cat, nonCat)
#       6         n = len(cat) + len(nonCat)
#       7         chi_values[term] = chi_square(n, a, b, c, d)
#
# <ipython-input-60-bde4ca5f7a44> in findOccurrences(term, C, notC)
#      10             c += 1
#      11     for item in notC:
# ---> 12         if term in item:
#      13             b += 1
#      14         else:
#
# KeyboardInterrupt:

# %%
print(chi_values_bi)
# Out:
# {'neural-networks': 811.6173060708263, 'neural-network': 704.1825505378162, 'deep-learning': 644.1259065033398, 'paper-propose': 591.7812931961296, 'machine-learning': 532.332667763701, 'propose-novel': 527.644296673662, 'deep-neural': 392.3059543115472, 'extensive-experiments': 389.4382709756346, 'experimental-results': 385.6066652923337, 'reinforcement-learning': 368.3673469387755, 'proposed-method': 356.3911265882768, 'available-https': 315.91243841739043, 'convolutional-neural': 310.97700597938973, 'magnetic-field': 299.18259134713094, 'training-data': 295.06970207017906, 'natural-language': 278.8339670468948, 'paper-proposes': 218.32825719120135, 'learning-models': 211.22810023629887, 'code-available': 211.20711434490426, 'state-of-the-art-methods': 206.51592380685824, 'outperforms-state-of-the-art': 197.9398101393658, 'demonstrate-effectiveness': 195.6514794978545, 'computer-vision': 193.5155224107222, 'proposed-approach': 184.6292204856292, 'work-propose': 177.48653946094532, 'state-of-the-art-performance': 169.42315449778135, 'publicly-available': 161.73367806307098, 'existing-methods': 156.15094314572207, 'benchmark-datasets': 154.1794729682068, 'effectiveness-proposed': 152.40902052383416, 'language-processing': 150.11838194549392, 'results-demonstrate': 149.26589713337845, 'learning-algorithms': 148.9082807431193, 'generative-adversarial': 147.07363755414525, 'object-detection': 145.044319097502, 'paper-presents': 143.61684110693358, 'phase-transition': 138.9474906558954, 'field-theory': 136.31402010606902, 'propose-new': 133.43125613447455, 'representation-learning': 132.87698812160258, 'learning-methods': 132.4863737636281, 'demonstrate-proposed': 132.43818328564092, 'paper-present': 131.93860792190668, 'language-models': 131.86370728270168, 'image-classification': 129.83745156257862, 'learning-framework': 127.81160368338952, 'standard-model': 127.25454300562703, 'state-art': 125.33366019400341, 'artificial-intelligence': 122.4895149140066, 'achieves-state-of-the-art': 121.73650586045575, 'graph-neural': 120.72434607645876, 'proposed-framework': 120.4936458203265, 'state-of-the-art-results': 119.71228811427997, 'models-trained': 119.71228811427997, 'learning-model': 118.85923419683235, 'source-code': 116.67672500502917, 'ground-state': 115.60364365789908, 'transfer-learning': 113.64207773922664, 'social-media': 113.64207773922664, 'experiments-demonstrate': 110.60279096532874, 'network-architecture': 108.5863663784436, 'experiments-conducted': 108.5863663784436, 'recent-years': 108.07503424883365, 'existing-approaches': 107.5755290805811, 'learning-rl': 107.5755290805811, 'data-augmentation': 107.5755290805811, 'recurrent-neural': 107.55215328140389, 'proposed-model': 107.03667685619007, 'semantic-segmentation': 106.56479340504674, 'deep-reinforcement': 105.55415933651672, 'prior-work': 103.53319595918983, 'datasets-demonstrate': 103.53319595918983, 'real-world-datasets': 101.51263882607167, 'proposed-algorithm': 98.76666375687438, 'problem-propose': 98.48256456637525, 'significantly-outperforms': 98.48256456637525, 'learning-based': 97.47274280259258, 'address-problem': 96.64656521199926, 'model-trained': 96.46302250803859, 'optimization-problem': 95.96654665628841, 'present-novel': 94.952657640933, 'speech-recognition': 94.4438862654476, 'classification-tasks': 93.43447028683377, 'compared-state-of-the-art': 93.15832602538852, 'attention-mechanism': 92.42515571629495, 'method-achieves': 92.42515571629495, 'loss-function': 91.86497379934393, 'federated-learning': 91.41594253855041, 'computational-complexity': 90.23162134944613, 'outperforms-existing': 89.39782030033649, 'model-performance': 88.38891120932101, 'simple-effective': 87.38010345000754, 'best-knowledge': 86.78427460575728, 'feature-extraction': 86.37139700713067, 'adversarial-networks': 86.37139700713067, 'machine-translation': 86.37139700713067, 'domain-adaptation': 85.36279186542806, 'improve-performance': 85.04428341384863, 'real-world-applications' ...

# %%
print(k_best_tri)
# Out:
# {'deep-neural-networks': 284.2431318252851, 'convolutional-neural-networks': 155.40651231961044, 'code-available-https': 155.19500151163962, 'convolutional-neural-network': 153.435194534182, 'natural-language-processing': 150.11838194549392, 'paper-propose-novel': 140.34559129935087, 'machine-learning-models': 114.65352509303027, 'reinforcement-learning-rl': 107.5755290805811, 'deep-learning-models': 106.56479340504674, 'deep-reinforcement-learning': 103.53319595918983, 'deep-neural-network': 101.3173157037755, 'experimental-results-demonstrate': 99.49248781468268, 'generative-adversarial-networks': 85.36279186542806, 'neural-networks-cnns': 79.313287485568, 'neural-networks-dnns': 78.30539102499749, 'graph-neural-networks': 74.2748168222423, 'recurrent-neural-network': 71.25294796527673, 'artificial-intelligence-ai': 67.22520443485676, 'deep-learning-based': 64.20545746388443, 'demonstrate-effectiveness-proposed': 63.19907709284245, 'work-propose-novel': 61.186619188525, 'paper-propose-new': 61.186619188525, 'neural-network-cnn': 60.539389140747076, 'recurrent-neural-networks': 60.18054162487462, 'automatic-speech-recognition': 58.16868919867616, 'adversarial-networks-gans': 56.15724027276374, 'internet-things-iot': 55.15166708448233, 'machine-learning-ml': 54.9632279727158, 'achieves-state-of-the-art-performance': 54.14619472575955, 'results-demonstrate-proposed': 53.14082318143079, 'graph-neural-network': 52.13555243633447, 'deep-learning-model': 52.13555243633447, 'long-short-term-memory': 52.13555243633447, 'language-processing-nlp': 50.12531328320802, 'generative-adversarial-network': 50.12531328320802, 'neural-network-architecture': 50.12531328320802, 'propose-novel-method': 47.11071016889691, 'outperforms-state-of-the-art-methods': 46.10604390097224, 'paper-proposes-novel': 46.10604390097224, 'effectiveness-proposed-method': 46.10604390097224, 'deep-convolutional-neural': 45.10147832623402, 'neural-architecture-search': 45.10147832623402, 'model-predictive-control': 45.10147832623402, 'extensive-experimental-results': 45.10147832623402, 'experimental-results-proposed': 45.10147832623402, 'machine-learning-methods': 44.097013429545, 'markov-decision-process': 44.097013429545, 'neural-network-models': 43.09264919577091, 'neural-networks-gnns': 43.09264919577091, 'deep-learning-methods': 43.09264919577091, 'machine-learning-algorithms': 42.53576069294226, 'propose-novel-approach': 42.08838560978054, 'neural-machine-translation': 42.08838560978054, 'federated-learning-fl': 42.08838560978054, 'conduct-extensive-experiments': 42.08838560978054, 'speech-recognition-asr': 41.08422265644571, 'publicly-available-https': 40.08016032064128, 'demonstrate-proposed-method': 40.08016032064128, 'pre-trained-language-models': 40.08016032064128, 'extensive-experiments-demonstrate': 39.07619858724513, 'extensive-experiments-conducted': 39.07619858724513, 'code-publicly-available': 37.06857686720433, 'results-proposed-method': 37.06857686720433, 'deep-learning-dl': 36.0649168503306, 'paper-present-novel': 36.0649168503306, 'source-code-available': 35.06135737540696, 'unsupervised-domain-adaptation': 35.06135737540696, 'stochastic-gradient-descent': 35.06135737540696, 'named-entity-recognition': 33.05453999098513, 'neural-network-architectures': 33.05453999098513, 'publicly-available-datasets': 33.05453999098513, 'address-problem-propose': 32.05128205128205, 'achieves-state-of-the-art-results': 32.05128205128205, 'channel-state-information': 31.048124593119336, 'deep-learning-techniques': 31.048124593119336, 'reinforcement-learning-drl': 31.048124593119336, 'predictive-control-mpc': 31.048124593119336, 'paper-proposes-new': 31.048124593119336, 'propose-novel-framework': 30.045067601402103, 'neural-network-dnn': 30.045067601402103, 'paper-presents-novel': 30.045067601402103, 'machine-learning-model': 30.045067601402103, 'short-term-memory-lstm': 30.045067601402103, 'natural-language-understanding': 30.045067601402103, 'compared-state-of-the- ...

# %%
# Filter by chi value chiVal
def selectChiBest(features, chiVal):
    features = {a: v for a, v in sorted(features.items(), key=lambda item: item[1], reverse=True)}
    features = {a: features[a] for a in features if features[a]>chiVal}
    return features

# %%
chiVal = 40
chi_best_uni = selectChiBest(chi_values_uni, chiVal)
chi_best_bi = selectChiBest(chi_values_bi, chiVal)
chi_best_tri = selectChiBest(chi_values_tri, chiVal)

print(chi_best_tri)
# Out:
# {'learning': 3074.555727628824, 'performance': 2010.4689464368037, 'propose': 1983.241364151793, 'training': 1730.4314799450503, 'neural': 1683.8631816980946, 'network': 1675.0816596235015, 'proposed': 1493.1499893307441, 'state-of-the-art': 1458.8801792902048, 'networks': 1319.256899424778, 'datasets': 1308.4952885159469, 'tasks': 1274.162310277148, 'paper': 1270.8325912890202, 'deep': 1270.7254235896041, 'methods': 1180.2468065922649, 'task': 1163.6485800431856, 'dataset': 1015.9301079371821, 'novel': 974.2526276775709, 'algorithm': 963.961135042794, 'algorithms': 948.0219606621092, 'data': 904.7918254168274, 'quantum': 891.0567042852821, 'existing': 885.0343032624083, 'problem': 848.6676126648457, 'information': 778.8527239955812, 'accuracy': 751.715600216933, 'experiments': 729.9527319418962, 'trained': 721.9994159707878, 'image': 714.1670870478893, 'learn': 698.6483803885063, 'machine': 694.5127933736717, 'method': 691.5837757604637, 'outperforms': 687.7806432287872, 'research': 670.9248027481079, 'language': 653.158644987001, 'mass': 643.9503292751087, 'achieves': 618.4002424385726, 'classification': 606.3730873416795, 'real-world': 605.0512819189297, 'architecture': 586.6878698451046, 'knowledge': 581.8136212567767, 'approaches': 576.2771377466798, 'energy': 575.4285496960309, 'images': 565.334240128809, 'magnetic': 564.6900717579748, 'models': 558.5910096594895, 'temperature': 556.6719618077198, 'effectiveness': 554.1945384501564, 'approach': 551.9424218547755, 'evaluation': 545.1743223762658, 'field': 539.358829571019, 'input': 524.7296791509854, 'better': 523.5292183235226, 'based': 509.2102219755699, 'demonstrate': 502.01104695563396, 'density': 499.7815621355926, 'improve': 498.3170194842251, 'theory': 498.0208335260993, 'framework': 495.85576775708324, 'adversarial': 479.05405609964964, 'human': 474.89313873987675, 'convolutional': 473.85780429465103, 'extensive': 473.75423998800625, 'design': 470.025388089027, 'evaluate': 464.84894785356386, 'challenging': 456.68185870320525, 'matter': 455.416277810204, 'users': 454.6255193721368, 'user': 453.1098966169838, 'spin': 448.79987397534404, 'achieve': 448.02515302040894, 'train': 447.3095106087433, 'available': 443.80924079799814, 'https': 441.59102594064035, 'semantic': 436.3153323455781, 'optimization': 425.1868781409826, 'transition': 422.39886583337767, 'phase': 421.1862596461663, 'online': 420.51197133746916, 'recognition': 417.3504490864203, 'visual': 416.8806929423386, 'complexity': 405.9779726968397, 'code': 405.5090318402333, 'address': 403.61534201137437, 'benchmark': 403.3429422618508, 'problems': 402.04676751357204, 'learned': 389.9852404546081, 'text': 386.56990459018857, 'model': 375.64478321515907, 'reinforcement': 372.0470262433147, 'coupling': 369.5456649114994, 'symmetry': 362.69385633960445, 'efficient': 361.16683698026196, 'calculations': 360.65344567412774, 'quality': 353.7932882520767, 'feature': 352.2082988631174, 'states': 347.54181054162405, 'emission': 341.3444792755138, 'multiple': 337.1935135135135, 'segmentation': 336.16610333172383, 'architectures': 333.1865939911153, 'lattice': 331.9148568739503, 'labels': 326.0262562588144, 'electron': 321.0996388425441, 'star': 319.5037064395478, 'features': 318.8987383125966, 'work': 318.7810205963946, 'generative': 312.53321994259596, 'end-to-end': 311.5034263399362, 'scattering': 310.97700597938973, 'benchmarks': 308.7064892647483, 'video': 307.7109117789108, 'proposes': 307.5457731876182, 'techniques': 307.2283157991433, 'properties': 306.14878987512225, 'attention': 305.48829668170356, 'vision': 303.69666751821035, 'dark': 303.2975066064975, 'computational': 300.1059221040005, 'challenges': 299.899173145777, 'particles': 298.75913649498557, 'observed': 296.8700517080614, 'formation': 296.59489412009793, 'equation': 295.37453640758315, 'automatic': 294.32253570184605, 'limit': 292.74919249968536, 'popular': 291.41012964246204, 'baseline': 289.21975743672266, '\\mathbb': 285.94403602269534, '\\rm': 2 ...

# %%
import json
chi_vals = [chi_best_uni, chi_best_bi, chi_best_tri]
with open('chi_data.json', 'w') as f:
    json.dump(chi_vals, f)

# %%
# Make unified df
df_combined = df_cs[['abstract', 'list_categories', 'main_categories']].copy()
df_tmp = df_random[['abstract', 'list_categories', 'main_categories']].copy()
df_combined = df_combined.append(df_tmp)

df_combined
# Out:
#                                                  abstract  \
# 92635     This chapter focuses on the performance enha...
# 160796    Much recent work suggests that incorporating...
# 304315    Hierarchical structures exist in both lingui...
# 21770     Multi-class novelty detection is increasingl...
# 122056    This paper develops KL-Ergodic Exploration f...
# ...                                                   ...
# 185341    Quantum impurities serve as in-situ probes o...
# 13291     We prove a general result about the stabilit...
# 231869    We consider quantum stochastic processes and...
# 11282     In this paper we study ideals arising from m...
# 174973    We study the equation \begin{equation*}\labe...
#
#                        list_categories       main_categories
# 92635                 [cs.IT, math.IT]            [cs, math]
# 160796                         [cs.CL]                  [cs]
# 304315                         [cs.CL]                  [cs]
# 21770                          [cs.CV]                  [cs]
# 122056                         [cs.RO]                  [cs]
# ...                                ...                   ...
# 185341               [cond-mat.str-el]            [cond-mat]
# 13291                        [math.DG]                [math]
# 231869  [cond-mat.stat-mech, quant-ph]  [cond-mat, quant-ph]
# 11282      [math.AC, math.ST, stat.TH]          [math, stat]
# 174973                       [math.AP]                [math]
#
# [20000 rows x 3 columns]

# %%
# Filter
def filterAbstract(text, chi_best_bi, chi_best_tri):
    tokens = word_tokenize(text)
    tokens = [w.lower() for w in tokens if w not in punctuation]
    # Find trigrams
    i = 0
    new1 = []
    while(i<len(tokens)-2):
        trigram = tokens[i]+'-'+tokens[i+1]+'-'+tokens[i+2]
        if(trigram in chi_best_tri):
            new1.append(trigram)
            i += 3
        else:
            new1.append(tokens[i])
            i += 1
    
    #Find bigrams
    i = 0
    new2 = []
    while(i<len(new1)-1):
        bigram = new1[i]+'-'+new1[i+1]
        if(bigram in chi_best_bi):
            new2.append(bigram)
            i += 2
        else:
            new2.append(new1[i])
            i += 1

    return new2

# %%
df_combined['filteredAbstracts'] = df_combined.abstract.apply(filterAbstract, chi_best_bi = chi_best_bi, chi_best_tri = chi_best_tri)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-4af646bed29c> in <module>
# ----> 1 df_combined['filteredAbstracts'] = df_combined.abstract.apply(filterAbstract, chi_best_bi = chi_best_bi, chi_best_tri = chi_best_tri)
#
# NameError: name 'chi_best_bi' is not defined

# %%
print(list(df_combined.filteredAbstracts.head(3)))
# Out:
# [['this', 'chapter', 'focuses', 'on', 'the', 'performance', 'enhancement', 'brought', 'by', 'the', 'addition', 'of', 'caching', 'capabilities', 'to', 'full-duplex', 'fd', 'radios', 'in', 'the', 'context', 'of', 'ultra-dense', 'networks', 'udns', 'more', 'specifically', 'we', 'aim', 'at', 'showing', 'that', 'the', 'interference', 'footprint', 'of', 'such', 'networks', 'i.e.', 'the', 'major', 'bottleneck', 'to', 'overcome', 'to', 'observe', 'the', 'theoretical', 'fd', 'throughput', 'doubling', 'at', 'the', 'network', 'level', 'can', 'be', 'significantly', 'reduced', 'thanks', 'to', 'edge', 'caching', 'fundamental', 'results', 'show', 'that', 'most', 'of', 'the', 'gain', 'as', 'compared', 'to', 'their', 'half-duplex', 'hd', 'counterparts', 'can', 'be', 'achieved', 'by', 'such', 'networks', 'only', 'if', 'costly', 'modifications', 'to', 'their', 'infrastructure', 'are', 'performed', 'and/or', 'if', 'high-rate', 'signaling', 'is', 'exchanged', 'between', 'user', 'equipments', 'ues', 'over', 'suitable', 'control', 'links', 'therefore', 'we', 'aim', 'at', 'proposing', 'a', 'viable', 'and', 'cost-effective', 'alternative', 'to', 'these', 'solutions', 'based', 'on', 'pre-fetching', 'locally', 'popular', 'contents', 'at', 'the', 'network', 'edge', 'we', 'start', 'by', 'considering', 'an', 'interference-rich', 'scenario', 'such', 'as', 'an', 'ultra-dense', 'fd', 'small-cell', 'network', 'in', 'which', 'several', 'non-cooperative', 'fd', 'base', 'stations', 'bss', 'serve', 'their', 'associated', 'ues', 'while', 'communicating', 'with', 'a', 'wireless', 'backhaul', 'node', 'bn', 'to', 'retrieve', 'the', 'content', 'to', 'deliver', 'we', 'then', 'describe', 'a', 'geographical', 'caching', 'policy', 'aiming', 'at', 'capturing', 'local', 'files', 'popularity', 'and', 'compute', 'the', 'corresponding', 'cache-hit', 'probability', 'thereupon', 'we', 'calculate', 'the', 'probability', 'of', 'successful', 'transmission', 'of', 'a', 'file', 'requested', 'by', 'a', 'ue', 'either', 'directly', 'by', 'its', 'serving', 'small-cell', 'base', 'station', 'sbs', 'or', 'by', 'the', 'corresponding', 'bn', 'this', 'quantity', 'is', 'then', 'used', 'to', 'lower-bound', 'the', 'throughput', 'of', 'the', 'considered', 'network', 'our', 'approach', 'leverages', 'tools', 'from', 'stochastic', 'geometry', 'in', 'order', 'to', 'guarantee', 'both', 'analytical', 'tractability', 'of', 'the', 'problem', 'and', 'generality', 'of', 'the', 'results', 'our', 'numerical', 'simulations', 'show', 'that', 'shifting', 'from', 'cache-free', 'to', 'cache-aided', 'fd', 'small-cell', 'networks', 'yields', 'a'], ['much', 'recent', 'work', 'suggests', 'that', 'incorporating', 'syntax', 'information', 'from', 'dependency', 'trees', 'can', 'improve', 'task-specific', 'transformer', 'models', 'however', 'the', 'effect', 'of', 'incorporating', 'dependency', 'tree', 'information', 'into', 'pre-trained', 'transformer', 'models', 'e.g.', 'bert', 'remains', 'unclear', 'especially', 'given', 'recent', 'studies', 'highlighting', 'how', 'these', 'models', 'implicitly', 'encode', 'syntax', 'in', 'this', 'work', 'we', 'systematically', 'study', 'the', 'utility', 'of', 'incorporating', 'dependency', 'trees', 'into', 'pre-trained', 'transformers', 'on', 'three', 'representative', 'information', 'extraction', 'tasks', 'semantic', 'role', 'labeling', 'srl', 'named', 'entity', 'recognition', 'and', 'relation', 'extraction', 'we', 'propose', 'and', 'investigate', 'two', 'distinct', 'strategies', 'for', 'incorporating', 'dependency', 'structure', 'a', 'late', 'fusion', 'approach', 'which', 'applies', 'a', 'graph-neural', 'network', 'on', 'the', 'output', 'of', 'a', 'transformer', 'and', 'a', 'joint', 'fusion', 'approach', 'which', 'infuses', 'syntax', 'structure', 'into', 'the', 'transformer', 'attention', 'layers', 'these', 'strategies', 'are', 'representative', 'of', 'prior-work', 'but', 'we', 'introduce', 'additional', 'model', 'design', 'elements', 'that', 'are', 'necessary', 'for', 'obtaining', 'i ...

# %%
def filterAdvance(text):
    return [w for w in text if w in chi_best_uni or w in chi_best_bi or w in chi_best_tri]

# %%
# Remove stop words
df_combined['filteredAbstracts'] = df_combined.filteredAbstracts.apply(clean)

# %%
# Filter out unigrams as well
df_combined['doubleFilteredAbstracts'] = df_combined.filteredAbstracts.apply(filterAdvance)

# %%
# Make a list of unified abstracts
abstracts = []
for item in df_combined.filteredAbstracts:
    abstracts.extend(item)

# %%
import itertools
with open('abstracts.txt', 'w') as f:
    f.write(str(abstracts))

# %%
corpus = " ".join(abstracts)
with open('../glove/merged_abstracts.txt', 'w') as f:
    f.write(corpus)

# %%
y_sub = []
for x in df_combined.list_categories:
    for elem in x:
        if(elem.split('.')[0]=='cs'):
            y_sub.append(elem)
            break

# %% [markdown]
# GLoVe Embeddings

# %%
import json
chi_values_list = []
with open('chi_data.json') as f:
    for jsonObj in f:
        chi_values_dict = json.loads(jsonObj)
        chi_values_list.append(chi_values_dict)

# %%
chi_values_list = chi_values_list[0]

# %%
import numpy as np
vectors_path = '../glove/vectors.txt' # Change this to the relative path on your machine

def load_glove_model(File):
    glove_model = {}
    with open(File,'r') as f:
        for line in f:
            split_line = line.split()
            word = split_line[0]
            embedding = np.array(split_line[1:], dtype=np.float64)
            glove_model[word] = embedding
    print(f"{len(glove_model)} words loaded!")
    return glove_model

vectors = load_glove_model(vectors_path)
print(vectors['paper'])
# Out:
# 21949 words loaded!
# [ 1.241946  0.446421 -0.279749  0.513549  1.010215  0.503216  0.594217
#  -0.655371  0.048609 -0.344555  0.896617 -0.43124  -0.078138 -0.872153
#   0.409776 -1.180427 -1.248342  0.453716 -0.460552  0.167306 -0.740122
#   0.814786  0.637907 -0.110531  1.306987  0.281991  0.097023  0.535167
#   0.205645 -0.891433  0.129538  1.218989 -1.001183  0.218944  1.317909
#   0.422249 -0.12527  -0.630907 -0.875215 -0.691199  1.237175 -0.278592
#  -0.808216 -0.135097  0.1419   -1.26455  -1.164269 -0.903209  0.489848
#   0.760575]

# %%
print(vectors['paper'].shape)
# Out:
# (50,)

# %%
def createVectors(all_terms, vectors):
    termDict = {}
    for term in all_terms:
        try:
            termDict[term] = vectors[term]
        except:
            print(term)
    return termDict

# %%
def vec2term(vector, vectors):
    for vec in vectors:
        if vec.value().all == vector:
            return vec.key()
    return "NO MATCH"

# %%
all_terms = list(chi_values_list[0].keys()) + list(chi_values_list[1].keys()) + list(chi_values_list[2].keys())
termDict = createVectors(all_terms, vectors)
# Out:
# paper-propose
# available-https
# demonstrate-effectiveness
# work-propose
# effectiveness-proposed
# language-processing
# field-theory
# demonstrate-proposed
# paper-present
# standard-model
# state-art
# graph-neural
# learning-rl
# deep-reinforcement
# problem-propose
# address-problem
# compared-state-of-the-art
# simple-effective
# adversarial-networks
# results-proposed
# networks-dnns
# schr\-''
# end-propose
# code-available-https
# paper-propose-novel
# neural-networks-cnns
# neural-networks-dnns

# %%
print(len(all_terms))
# Out:
# 986

# %% [markdown]
# Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from scipy.spatial.distance import cdist
from sklearn import metrics

# %%
k = 10
kmeans = KMeans(n_clusters=k, random_state=42)

np_vectors= list(termDict.values())

# %%
import math
for i in range(len(np_vectors)):
    if(np.isnan(np.sum(np_vectors[i]))):
        np_vectors[i] = [0]*50

# %%
def kMeansPredict(np_vector):
    return kmeans.fit_predict(np_vector)

y_pred= kMeansPredict(np_vectors)

# %% [markdown]
# Visualisation

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, verbose=0, perplexity=50, n_iter=1000, random_state=0)
tsne_results = tsne.fit_transform(np_vectors)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(15,15)})

palette = sns.hls_palette(k, l=.4, s=.9)

sns.scatterplot(tsne_results[:,0], tsne_results[:,1], hue=y_pred, palette=palette, legend='full')
# Out:
# /Users/miamijovic/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#Find nearest neighbours of a term
from scipy.spatial import distance
def findNearestNeighbour(term, vectors):
    term_vec = vectors[term]
    tmp = {k: v for k,v in sorted(vectors.items(), key=lambda item: distance.cosine(term_vec, item[1]))}
    nearest = list({k: tmp[k] for k in list(tmp)[:10]}.keys())

    return nearest

# %%
n = findNearestNeighbour('deep-neural-networks', vectors)
neighbourTerms = pd.DataFrame({n[0]:n[1:]})
n = findNearestNeighbour('computer-vision', vectors)
neighbourTerms[n[0]] = n[1:]
n = findNearestNeighbour('natural-language-processing', vectors)
neighbourTerms[n[0]] = n[1:]
n = findNearestNeighbour('algorithm', vectors)
neighbourTerms[n[0]] = n[1:]
n = findNearestNeighbour('machine-learning', vectors)
neighbourTerms[n[0]] = n[1:]

neighbourTerms
# Out:
#             deep-neural-networks              computer-vision  \
# 0                           dnns  natural-language-processing
# 1                            dnn                          nlp
# 2                  deep-learning                deep-learning
# 3  convolutional-neural-networks             image-processing
# 4                neural-networks             machine-learning
# 5           deep-learning-models                        tasks
# 6                  architectures                 applications
# 7        machine-learning-models                 recent-years
# 8                           cnns         image-classification
#
#   natural-language-processing     algorithm         machine-learning
# 0                         nlp        method            deep-learning
# 1             computer-vision    algorithms               techniques
# 2                   nlp-tasks      approach                    tools
# 3            image-processing     iterative               approaches
# 4                  biomedical      proposed          computer-vision
# 5                 mathematics       optimal  machine-learning-models
# 6                       tasks     procedure                developed
# 7                 engineering  optimization             applications
# 8              image-analysis          uses               frameworks

# %% [markdown]
# Silhouette Score for determining the best number of clusters

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
range_n_clusters = [2, 5, 10, 15, 20, 25, 30, 35, 38, 40, 45]

def silhouette(range_n_clusters):
    for n_clusters in range_n_clusters:
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(np_vectors)

        silhouette_avg = silhouette_score(np_vectors, cluster_labels)
        print(
            "For n_clusters =",
            n_clusters,
            "The average silhouette_score is :",
            silhouette_avg,
        )
silhouette(range_n_clusters)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.110382001709372
# For n_clusters = 5 The average silhouette_score is : 0.06675037126959041
# For n_clusters = 10 The average silhouette_score is : 0.06647249092778043
# For n_clusters = 15 The average silhouette_score is : 0.06052493349189961
# For n_clusters = 20 The average silhouette_score is : 0.05728321939093926
# For n_clusters = 25 The average silhouette_score is : 0.058553261095907784
# For n_clusters = 30 The average silhouette_score is : 0.060839974225620784
# For n_clusters = 35 The average silhouette_score is : 0.05985172496856492
# For n_clusters = 38 The average silhouette_score is : 0.05960038198147204
# For n_clusters = 40 The average silhouette_score is : 0.06165542654619694
# For n_clusters = 45 The average silhouette_score is : 0.061404478947509056

# %%
range_n_clusters = range(8,15)
silhouette(range_n_clusters)
# Out:
# For n_clusters = 8 The average silhouette_score is : 0.06555311851202908
# For n_clusters = 9 The average silhouette_score is : 0.06544304146077001
# For n_clusters = 10 The average silhouette_score is : 0.06647249092778043
# For n_clusters = 11 The average silhouette_score is : 0.06298706782954504
# For n_clusters = 12 The average silhouette_score is : 0.06439519191179251
# For n_clusters = 13 The average silhouette_score is : 0.061462439257572214
# For n_clusters = 14 The average silhouette_score is : 0.05623354686794507

# %% [markdown]
# Elbow method for determining the best number of clusters

# %%
from sklearn import metrics
from scipy.spatial.distance import cdist

range_n_clusters = [2, 5, 10, 15, 20, 25, 30, 35, 38, 40, 45]

def elbow(range_n_clusters):
    distortions = []
    inertias = []
    mapping1 = {}
    mapping2 = {}
    for n_clusters in range_n_clusters:
        clusterer = KMeans(n_clusters=n_clusters, random_state=10)
        cluster_labels = clusterer.fit_predict(np_vectors)

        distortions.append(sum(np.min(cdist(np_vectors, clusterer.cluster_centers_,
                                            'euclidean'), axis=1)) / len(np_vectors))
        inertias.append(clusterer.inertia_)
    
        mapping1[k] = sum(np.min(cdist(np_vectors, clusterer.cluster_centers_,
                                    'euclidean'), axis=1)) / len(np_vectors)
        mapping2[k] = clusterer.inertia_

    plt.plot(range_n_clusters, distortions, 'bx-')
    plt.xlabel('Values of K')
    plt.ylabel('Distortion')
    plt.title('The Elbow Method using Distortion')
    plt.show()

elbow(range_n_clusters)

# %%
range_n_clusters = range(8,16)
elbow(range_n_clusters)

# %%
import matplotlib.cm as cm

clusterer = KMeans(n_clusters=k, random_state=42)
cluster_labels = clusterer.fit_predict(np_vectors)
#tsne_results = tsne.fit_transform(np_vectors)
fig, (ax1) = plt.subplots(1, 1)

colors = cm.nipy_spectral(cluster_labels.astype(float) / k)
ax1.scatter(
        tsne_results[:, 0], tsne_results[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
    )

# Labeling the clusters
centers = clusterer.cluster_centers_
tsne_centers = tsne.fit_transform(centers)
# Draw white circles at cluster centers
ax1.scatter(
    tsne_centers[:, 0],
    tsne_centers[:, 1],
    marker="o",
    c="white",
    alpha=1,
    s=200,
    edgecolor="k",
)

for i, c in enumerate(tsne_centers):
    ax1.scatter(c[0], c[1], marker="$%d$" % i, alpha=0.7, s=50, edgecolor="k")

# %%
for center in centers:
    for k,v in vectors.items():
        if(v.all == center.all):
            print(k)

# %%
def findNearestNeighbourVec(term_vec, vectors):
    tmp = {k: v for k,v in sorted(vectors.items(), key=lambda item: distance.cosine(term_vec, item[1]))}
    nearest = list({k: tmp[k] for k in list(tmp)[:10]}.keys())

    return nearest

# %%
n = findNearestNeighbourVec(centers[0], vectors)
neighbourTerms2 = pd.DataFrame({n[0]:n[1:]})
for i in range(len(centers)):
    n = findNearestNeighbourVec(centers[i], vectors)
    print(i,n)
    neighbourTerms2[n[0]] = n[1:]

neighbourTerms2
# Out:
# 0 ['electron', 'fluctuations', 'thermal', 'polarization', 'magnetic', 'spin', 'temperature', 'energy', 'density', 'charge']
# 1 ['text', 'image', 'semantic', 'task', 'representations', 'target', 'visual', 'learn', 'images', 'input']
# 2 ['proposed-method', 'experimental-results', 'demonstrate', 'proposed-approach', 'state-of-the-art-methods', 'effectiveness', 'benchmarks', 'outperforms', 'proposed-model', 'experiments']
# 3 ['approach', 'framework', 'proposed', 'propose', 'method', 'use', 'based', 'design', 'methods', 'addition']
# 4 ['computational', 'limited', 'however', 'resources', 'lack', 'required', 'because', 'need', 'therefore', 'address']
# 5 ['theory', 'form', 'field', 'finite', 'particular', 'case', 'equations', 'general', 'existence', 'corresponding']
# 6 ['deep', 'cnn', 'deep-neural-network', 'deep-learning', 'neural-network', 'architectures', 'generative-models', 'supervised', 'transformer', 'self-supervised']
# 7 ['m', 's', 'p', 't', '\\in', 'h', 'd', 'f', '0', 'x']
# 8 ['environment', 'users', 'user', 'development', 'real-time', 'mobile', 'services', 'ai', 'deployment', 'autonomous']
# 9 ['mass', 'star', 'formation', 'stellar', 'find', 'observed', 'masses', 'stars', 'halo', 'gas']
#        electron             text           proposed-method   approach  \
# 0  fluctuations            image      experimental-results  framework
# 1       thermal         semantic               demonstrate   proposed
# 2  polarization             task         proposed-approach    propose
# 3      magnetic  representations  state-of-the-art-methods     method
# 4          spin           target             effectiveness        use
# 5   temperature           visual                benchmarks      based
# 6        energy            learn               outperforms     design
# 7       density           images            proposed-model    methods
# 8        charge            input               experiments   addition
#
#   computational         theory                 deep    m  environment  \
# 0       limited           form                  cnn    s        users
# 1       however          field  deep-neural-network    p         user
# 2     resources         finite        deep-learning    t  development
# 3          lack     particular       neural-network  \in    real-time
# 4      required           case        architectures    h       mobile
# 5       because      equations    generative-models    d     services
# 6          need        general           supervised    f           ai
# 7     therefore      existence          transformer    0   deployment
# 8       address  corresponding      self-supervised    x   autonomous
#
#         mass
# 0       star
# 1  formation
# 2    stellar
# 3       find
# 4   observed
# 5     masses
# 6      stars
# 7       halo
# 8        gas
